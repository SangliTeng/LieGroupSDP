# %%
using DynamicPolynomials
using TSSOS
using MAT
using LinearAlgebra
using Printf
using JuMP

using Distributed

# %%
@polyvar temp1[1:4, 1:4]
@polyvar temp2[1:4, 1:4]
temp_p = temp2 * 1.1 + temp1 * 1.1

function Joint2SE3(c, s, x, y, z)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[2,2] = c
    T[1,2] = -s
    T[2,1] = s
    T[3,3] = 1
    
    T[1,4] = c * x - s * y
    T[2,4] = s * x + c * y
    T[3,4] = z
    T[4,4] = 1
    return T
end

function SE3_Euler_num(y, p, r, lx, ly, lz)
    T = temp_p * 0
    T[1:3, 1:3] = rotz_num(y) * roty_num(p) * rotx_num(r)
    T[4,4] = 1.0
    T[1,4] = lx
    T[2,4] = ly
    T[3,4] = lz
    return T
end

function rotx_num(t)
    R = temp_p[1:3, 1:3] * 0
    R[2,2] = cos(t)
    R[3,3] = cos(t)
    R[2,3] = -sin(t)
    R[3,2] = sin(t)
    R[1,1] = 1.0
    return R
end

function roty_num(t)
    R = temp_p[1:3, 1:3] * 0
    R[1,1] = cos(t)
    R[3,3] = cos(t)
    R[1,3] = sin(t)
    R[3,1] = -sin(t)
    R[2,2] = 1.0
    return R
end

function rotz_num(t)
    R = temp_p[1:3, 1:3] * 0
    R[1,1] = cos(t)
    R[2,2] = cos(t)
    R[1,2] = -sin(t)
    R[2,1] = sin(t)
    R[3,3] = 1.0
    return R
end

function quat2rot_num(w, x, y, z)
    R = temp_p[1:3, 1:3] * 0
    nq = sqrt(w^2 + x^2 + y^2 + z^2)
    w = w / nq
    x = x / nq
    y = y / nq
    z = z / nq
    
    R[1,1] = 1 - 2 * (y^2 + z^2)
    R[2,2] = 1 - 2 * (x^2 + z^2)
    R[3,3] = 1 - 2 * (x^2 + y^2)
    
    R[1,2] = 2 * (x * y - w * z)
    R[1,3] = 2 * (w * y + x * z)
    R[2,3] = 2 * (y * z - w * x)
    
    R[2,1] = 2 * (x * y + w * z)
    R[3,1] = 2 * (- w * y + x * z)
    R[3,2] = 2 * (y * z + w * x)
    return R
end

function cross_(x, y) 
    z = temp_p[1:3, 1]
    z[1] = -x[3] * y[2] + x[2] * y[3]
    z[2] =  x[3] * y[1] - x[1] * y[3]
    z[3] = -x[2] * y[1] + x[1] * y[2]
    return z
end

function add_SO3_cons(R, eq)
    T = R' * R
#     print(T[1,1] - 1.0)
    append!(eq, [T[1,1] - 1.0])
    append!(eq, [T[2,2] - 1.0])
    append!(eq, [T[3,3] - 1.0])
    append!(eq, [T[1,2]])
    append!(eq, [T[1,3]])
    append!(eq, [T[2,3]])
    
    append!(eq, cross_(R[1,:], R[2, :]) - R[3,:])
    append!(eq, cross_(R[2,:], R[3, :]) - R[1,:])
    append!(eq, cross_(R[3,:], R[1, :]) - R[2,:])
    
    return eq
end

function add_SE3_tran_cons(T1, T2, eq)
    T = T1 - T2
    
    append!(eq, [T[1, 1]])
    append!(eq, [T[1, 2]])
    append!(eq, [T[1, 3]])
    
    
    append!(eq, [T[2, 1]])
    append!(eq, [T[2, 2]])
    append!(eq, [T[2, 3]])
    
    
    append!(eq, [T[3, 1]])
    append!(eq, [T[3, 2]])
    append!(eq, [T[3, 3]])
    
    append!(eq, [T[1, 4]])
    append!(eq, [T[2, 4]])
    append!(eq, [T[3, 4]])    
    return eq
end

function add_SO3_tran_cons(T1, T2, eq)
    T = T1 - T2
    
    append!(eq, [T[1, 1]])
    append!(eq, [T[1, 2]])
    append!(eq, [T[1, 3]])
    
    
    append!(eq, [T[2, 1]])
    append!(eq, [T[2, 2]])
    append!(eq, [T[2, 3]])
    
    
    append!(eq, [T[3, 1]])
    append!(eq, [T[3, 2]])
    append!(eq, [T[3, 3]])
    
    return eq
end


function make_SE3(R, x, y, z)
    T = temp_p * 0
    T[1:3, 1:3] = R
    T[1,4] = x
    T[2,4] = y
    T[3,4] = z
    T[4,4] = 1.0
    return T
end

function SE3_inverse(T)
    Tnew = T
    Tnew[1:3, 1:3] = T[1:3, 1:3]'
    Tnew[1:3, 4] = - T[1:3, 1:3]' * T[1:3, 4]
    return Tnew
end

# Joint2SE3(c[1], s[1], x[1], y[1], z[1])
# R = quat2rot_num(randn(), randn(), randn(), randn())
# R * R'
# rotz_num(c[1,1])
# T = SE3_Euler_num(randn(), randn(), randn(), randn(), randn(), randn())
# cross(R[1, 1,:], R[1, 2, :])

###########################################
function DH1(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[2,2] = c
    T[1,2] = -s
    T[2,1] = s
    T[3,3] = 1
    
    T[1,4] = 0
    T[2,4] = 0
    T[3,4] = 0
    
    T[4,4] = 1
    return T
end

function DH2(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[1,2] = -s
    T[3,2] = -c
    T[3,1] = -s
    T[2,3] = 1
    
    T[1,4] = 0.
    T[2,4] = 0
    T[3,4] = 0
    
    T[4,4] = 1
    return T
end

function DH3(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[2,2] = c
    T[1,2] = -s
    T[2,1] = s
    T[3,3] = 1
        
    T[1,4] = 431.8 / 1000
    T[2,4] = 0
    T[3,4] = 124.46 / 1000
    
    T[4,4] = 1
    return T
end

function DH4(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[1,2] = -s
    T[3,2] = -c
    T[3,1] = -s
    T[2,3] = 1

    
    T[1,4] = 20.32 / 1000
    T[2,4] = 431.8 / 1000
    T[3,4] = 0
    
    T[4,4] = 1
    return T
end

function DH5(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[1,2] = -s
    T[3,2] = c
    T[3,1] = s
    T[2,3] = -1

    
    T[1,4] = 0
    T[2,4] = 0.
    T[3,4] = 0
    
    T[4,4] = 1
    return T
end

function DH6(c, s)
    ## we always rotate about the z axis
    T = temp_p * 0
    T[1,1] = c
    T[1,2] = -s
    T[3,2] = -c
    T[3,1] = -s
    T[2,3] = 1

    
    T[1,4] = 0
    T[2,4] = 0.
    T[3,4] = 0
    
    T[4,4] = 1
    return T
end
# Out:
# DH6 (generic function with 1 method)

# %%
puma_goal = matread("puma_test_data.mat")
R_list = puma_goal["R_list"]
p_list = puma_goal["p_list"]

joint_list = puma_goal["sol_list"]
# Out:
# 1×14553 Matrix{Any}:
#  [-1.72701 -0.475237 … 0.848254 1.53816]  …  Matrix{Float64}(undef, 0, 0)

# %%
function puma_batch_test_hard(T_end)
    
#     ub = [60, 45, 75, 135, 100, 180] * pi / 180
#     lb = [-60, -225, -250, -135, -100, -180] * pi / 180
    
#     ub = [180, 45, 75, 135, 100, 180] * pi / 180
#     lb = [-180, -225, -250, -135, -100, -180] * pi / 180

    ub = [170, 45, 75, 135, 100, 180] * pi / 180
    lb = [-170, -225, -250, -135, -100, -180] * pi / 180

    dof = 6
    
    @polyvar R[1:dof+1, 1:3, 1:3] 
    @polyvar c[1:dof]
    @polyvar s[1:dof]
    @polyvar x[1:dof+1]
    @polyvar y[1:dof+1]
    @polyvar z[1:dof+1]
    var = append!(reshape(R, (1+dof) * 9), c, s, x, y, z)
    # print(var)

    eq = [temp_p[1,1] * 0]
    ineq = []

    eq[1] = R[1, 1, 1] - 1.0
    append!(eq, [R[1, 1, 2] - 0.0])
    append!(eq, [R[1, 1, 3] - 0.0])
    append!(eq, [R[1, 2, 1] - 0.0])
    append!(eq, [R[1, 2, 2] - 1.0])
    append!(eq, [R[1, 2, 3] - 0.0])
    append!(eq, [R[1, 3, 1] - 0.0])
    append!(eq, [R[1, 3, 2] - 0.0])
    append!(eq, [R[1, 3, 3] - 1.0])

    append!(eq, [x[1] - 0.0])
    append!(eq, [y[1] - 0.0])
    append!(eq, [z[1] - 0.0])

    f_act = 0

    for k = 1:dof

        append!(eq, [c[k]^2 + s[k]^2 - 1]) # joint SO2 constrains
        eq = add_SO3_cons(R[k+1,:,:], eq) # SO3 constraints

        Tk = make_SE3(R[k,:,:], x[k], y[k], z[k])
        Tkp1 = make_SE3(R[k+1,:,:], x[k+1], y[k+1], z[k+1])

        if k == 1
            Act = DH1(c[k], s[k])
            mid = (ub[k] + lb[k]) / 2
        end
        if k == 2
            Act = DH2(c[k], s[k])
        end
        if k == 3
            Act = DH3(c[k], s[k])
        end
        if k == 4
            Act = DH4(c[k], s[k])
        end
        if k == 5
            Act = DH5(c[k], s[k])
        end
        if k == 6
            Act = DH6(c[k], s[k])
        end
        
        mid = (ub[k] + lb[k]) / 2
        r = (ub[k] - lb[k]) / 2
        
        append!(ineq, [c[k] * cos(mid) + s[k] * sin(mid) - cos(r)])  # cos(t - t0) >= cos(r)

        eq = add_SE3_tran_cons(Tkp1, Tk * Act, eq)
        # append!(ineq, [100 - (x[k+1]^2 + y[k+1]^2 + z[k+1]^2)])
        
        f_act = f_act + (1 - c[k])^2 + s[k]^2
    end

    

    R_goal = T_end[1:3, 1:3] 

    R_diff = R[end, :, :] - R_goal
    R_diff = R_diff' * R_diff
    f_R = R_diff[1,1] + R_diff[2,2] + R_diff[3,3]
    f_p = (x[end] - T_end[1, 4])^2 + (y[end] - T_end[2, 4])^2 + (z[end] - T_end[3, 4])^2
    
    for i = 1:3
        for j = 1:3
            append!(eq, [ R_goal[i,j] - R[end, i, j] ])
        end
    end
    
    append!(eq, [ x[end] - T_end[1, 4] ])
    append!(eq, [ y[end] - T_end[2, 4] ])
    append!(eq, [ z[end] - T_end[3, 4] ])
    

    f = f_act # + f_R + f_p # * 1e-5 # 1e-3 * sum(var.^2)
    pop = append!([f * 1.0], ineq, eq)


    eq_len = length(eq)

    order = 2
    
    time_1_start = time()
    # you may need to modify this function to export the model information 
    # opt_1,sol,data,model,sol_approx = cs_tssos_first(pop, var, order, numeq=eq_len, CS="NC", TS=false, MomentOne=true, solution=true, QUIET=false);
    opt_1,sol,data = cs_tssos_first(pop, var, order, numeq=eq_len, CS="NC", TS=false, MomentOne=true, solution=true, QUIET=false);
    time_1_end = time()
    
    elapsed_1 = time_1_end - time_1_start
    
    moment = []
    for k = 1:length(data.moment)
        append!(moment, [convert(Matrix{Float64}, data.moment[k])]) # data.Mmatrix[k])
    end

    Tg = zeros(4, 4)
    for i = 1:4
        for j = 1:4
            Tg[i,j] = T_end[i, j]
        end
    end
    
    # flag = primal_status(model)
    # flag = string(flag)
    
    # flag2 = termination_status(model)
    # flag2 = string(flag2)
    
    log = Dict("sol" => sol, "dof" => dof, "moment" => moment, # "sol_approx" => sol_approx,
        "elapsed" => elapsed_1, "Tg" => Tg, #"flag"=>string(flag),
        "opt"=>opt_1) #"flag2"=>flag2)

    return log
end

puma_goal = matread("puma_test_data.mat")
R_list = puma_goal["R_list"]
p_list = puma_goal["p_list"]
for id = 1:3682
    T_end = zeros(4, 4)
    T_end[1:3, 1:3] = R_list[id, :, :]
    T_end[1:3, end] = p_list[id, :]
    T_end[end, end] = 1
    log = puma_batch_test_hard(T_end)
    file_name = "MD_puma_"  *string(id) * ".mat"
#     matwrite(file_name, log)
end
# Out:
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.1036687 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.9006447 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138673161e-01   2.523003384e-01   9.3e-01  0.33
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.381505122e-01  -1.039238948e+00  7.4e-01  0.44
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.819266017e+00   8.784902151e-01   4.3e-01  0.56
# 4   1.5e+00  1.7e-01  1.7e-01  -5.49e-01  6.679014720e+00   6.017158422e+00   1.7e-01  0.67
# 5   1.2e+00  1.3e-01  1.2e-01  3.63e-01   7.352105098e+00   6.821804323e+00   1.3e-01  0.80
# 6   5.6e-01  6.2e-02  4.1e-02  7.05e-01   9.035952174e+00   8.787126999e+00   6.2e-02  0.91
# 7   1.4e-01  1.6e-02  6.0e-03  8.00e-01   9.943624287e+00   9.851776580e+00   1.6e-02  1.03
# 8   4.2e-02  4.7e-03  6.2e-04  1.13e+00   9.426359925e+00   9.420808978e+00   4.7e-03  1.19
# 9   2.3e-02  2.6e-03  2.4e-04  1.62e+00   7.989446203e+00   7.985971156e+00   2.6e-03  1.30
# 10  1.7e-02  1.9e-03  1.6e-04  1.22e+00   7.807646545e+00   7.804361799e+00   1.9e-03  1.41
# 11  5.5e-03  6.1e-04  3.7e-05  1.01e+00   7.379362008e+00   7.377161124e+00   6.1e-04  1.53
# 12  1.4e-03  1.5e-04  5.4e-06  6.33e-01   7.042203269e+00   7.041428660e+00   1.5e-04  1.66
# 13  2.7e-04  3.0e-05  5.5e-07  7.80e-01   6.860204456e+00   6.859976517e+00   3.0e-05  1.78
# 14  3.6e-05  4.1e-06  3.0e-08  8.61e-01   6.800579842e+00   6.800540030e+00   4.1e-06  1.91
# 15  1.2e-05  1.4e-06  6.1e-09  9.66e-01   6.792077346e+00   6.792063009e+00   1.4e-06  2.02
# 16  2.3e-06  2.6e-07  5.1e-10  9.91e-01   6.788562538e+00   6.788559732e+00   2.6e-07  2.14
# 17  4.3e-07  4.7e-08  3.9e-11  9.98e-01   6.787894389e+00   6.787893872e+00   4.7e-08  2.28
# 18  7.7e-08  8.7e-09  2.8e-12  1.00e+00   6.787771070e+00   6.787770982e+00   8.2e-09  2.39
# 19  2.0e-08  2.9e-09  3.2e-13  1.00e+00   6.787751709e+00   6.787751689e+00   1.9e-09  2.53
# 20  3.8e-09  9.3e-09  2.4e-14  1.00e+00   6.787746898e+00   6.787746894e+00   3.4e-10  2.66
# Optimizer terminated. Time: 2.66
#
# SDP solving time: 6.799839 seconds.
# optimum = 6.787746897961996
# Global optimality certified with relative optimality gap 0.000070%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0013674 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0451051 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138700736e-01   2.523037865e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.385971976e-01  -1.039744957e+00  7.4e-01  0.42
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.819677375e+00   8.792385048e-01   4.3e-01  0.53
# 4   1.5e+00  1.7e-01  1.7e-01  -5.47e-01  6.683787241e+00   6.032761208e+00   1.7e-01  0.67
# 5   1.2e+00  1.3e-01  1.2e-01  3.55e-01   7.368845749e+00   6.844160407e+00   1.3e-01  0.78
# 6   5.7e-01  6.3e-02  4.2e-02  6.92e-01   9.087426290e+00   8.826243715e+00   6.3e-02  0.91
# 7   2.7e-01  3.0e-02  1.6e-02  7.63e-01   9.894296582e+00   9.725146417e+00   3.0e-02  1.02
# 8   6.2e-02  6.8e-03  1.5e-03  8.62e-01   1.017196183e+01   1.014679401e+01   6.8e-03  1.14
# 9   3.7e-02  4.1e-03  5.9e-04  1.71e+00   8.139017227e+00   8.128959382e+00   4.1e-03  1.27
# 10  1.7e-02  1.9e-03  1.7e-04  1.49e+00   7.119395518e+00   7.115116587e+00   1.9e-03  1.38
# 11  1.2e-02  1.3e-03  1.1e-04  9.22e-01   7.058481843e+00   7.054257617e+00   1.3e-03  1.49
# 12  3.0e-03  3.3e-04  1.9e-05  7.50e-01   6.770293866e+00   6.768087404e+00   3.3e-04  1.61
# 13  7.4e-04  8.3e-05  2.3e-06  7.73e-01   6.340915432e+00   6.340425109e+00   8.3e-05  1.74
# 14  8.2e-05  9.1e-06  8.7e-08  9.28e-01   6.200424810e+00   6.200364600e+00   9.1e-06  1.86
# 15  1.5e-05  1.7e-06  7.1e-09  9.93e-01   6.182169935e+00   6.182157089e+00   1.7e-06  1.99
# 16  2.9e-06  3.3e-07  6.4e-10  9.98e-01   6.178680639e+00   6.178677836e+00   3.3e-07  2.13
# 17  6.3e-07  7.1e-08  6.7e-11  1.00e+00   6.177965500e+00   6.177964856e+00   7.1e-08  2.23
# 18  1.3e-07  1.4e-08  5.3e-12  1.00e+00   6.177794863e+00   6.177794748e+00   1.3e-08  2.34
# 19  2.5e-08  3.5e-09  5.2e-13  1.00e+00   6.177765380e+00   6.177765357e+00   2.8e-09  2.50
# 20  4.9e-09  5.4e-09  4.3e-14  1.00e+00   6.177759085e+00   6.177759081e+00   5.3e-10  2.63
# Optimizer terminated. Time: 2.63
#
# SDP solving time: 2.7889158 seconds.
# optimum = 6.177759084950166
# Global optimality certified with relative optimality gap 0.000043%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0010007 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.044638 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.16
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138422504e-01   2.522664058e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.365334389e-01  -1.037450743e+00  7.4e-01  0.42
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.818584663e+00   8.770040024e-01   4.3e-01  0.55
# 4   1.5e+00  1.6e-01  1.7e-01  -5.52e-01  6.702931616e+00   6.014842482e+00   1.6e-01  0.67
# 5   1.2e+00  1.3e-01  1.2e-01  3.29e-01   7.433008145e+00   6.872202255e+00   1.3e-01  0.78
# 6   5.7e-01  6.3e-02  4.4e-02  6.50e-01   9.236256311e+00   8.933851526e+00   6.3e-02  0.88
# 7   2.7e-01  3.0e-02  1.7e-02  7.16e-01   1.031049083e+01   1.010962493e+01   3.0e-02  1.00
# 8   6.1e-02  6.7e-03  1.7e-03  8.10e-01   1.098063408e+01   1.094114370e+01   6.7e-03  1.13
# 9   2.1e-02  2.3e-03  2.1e-04  1.56e+00   9.695628377e+00   9.692502019e+00   2.3e-03  1.25
# 10  9.5e-03  1.1e-03  6.9e-05  1.44e+00   8.847219938e+00   8.845097113e+00   1.1e-03  1.39
# 11  6.1e-03  6.8e-04  4.3e-05  7.77e-01   8.768203165e+00   8.765910833e+00   6.8e-04  1.50
# 12  1.4e-03  1.6e-04  5.3e-06  7.53e-01   8.393860545e+00   8.393166774e+00   1.6e-04  1.63
# 13  3.1e-04  3.5e-05  6.0e-07  8.76e-01   8.179041177e+00   8.178849969e+00   3.5e-05  1.75
# 14  4.1e-05  4.6e-06  2.9e-08  9.34e-01   8.112669115e+00   8.112641905e+00   4.6e-06  1.88
# 15  6.7e-06  7.5e-07  2.0e-09  9.93e-01   8.103301531e+00   8.103296557e+00   7.5e-07  2.00
# 16  1.3e-06  1.5e-07  1.8e-10  1.00e+00   8.101781107e+00   8.101780024e+00   1.5e-07  2.13
# 17  2.6e-07  2.9e-08  1.6e-11  1.00e+00   8.101469308e+00   8.101469080e+00   2.9e-08  2.25
# 18  5.0e-08  8.0e-09  1.3e-12  1.00e+00   8.101404344e+00   8.101404303e+00   5.4e-09  2.38
# 19  1.1e-08  5.4e-09  1.1e-13  1.00e+00   8.101392787e+00   8.101392780e+00   1.0e-09  2.50
# 20  2.7e-09  3.2e-08  1.3e-14  1.00e+00   8.101390828e+00   8.101390826e+00   2.5e-10  2.63
# Optimizer terminated. Time: 2.63
#
# SDP solving time: 2.8076972 seconds.
# optimum = 8.101390827531345
# Global optimality certified with relative optimality gap 0.000011%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0143861 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0665227 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.17              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.19
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138696658e-01   2.523033102e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.385733651e-01  -1.039711689e+00  7.4e-01  0.42
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.818780178e+00   8.783592040e-01   4.3e-01  0.55
# 4   1.5e+00  1.7e-01  1.8e-01  -5.50e-01  6.669344511e+00   5.984974298e+00   1.7e-01  0.67
# 5   1.2e+00  1.3e-01  1.2e-01  3.27e-01   7.317700776e+00   6.772943228e+00   1.3e-01  0.78
# 6   5.7e-01  6.3e-02  4.4e-02  6.46e-01   8.874466989e+00   8.582207168e+00   6.3e-02  0.88
# 7   2.6e-01  2.9e-02  1.5e-02  7.28e-01   9.474488027e+00   9.284348919e+00   2.9e-02  1.00
# 8   4.9e-02  5.5e-03  1.5e-03  7.72e-01   9.555142434e+00   9.505387928e+00   5.5e-03  1.11
# 9   1.3e-02  1.5e-03  1.3e-04  1.21e+00   8.738948039e+00   8.736115747e+00   1.5e-03  1.25
# 10  5.4e-03  5.9e-04  3.0e-05  1.68e+00   8.301826275e+00   8.300670564e+00   5.9e-04  1.38
# 11  2.5e-03  2.8e-04  1.0e-05  1.13e+00   8.122232574e+00   8.121465192e+00   2.8e-04  1.50
# 12  1.2e-03  1.3e-04  4.4e-06  6.91e-01   8.123939907e+00   8.123229114e+00   1.3e-04  1.63
# 13  4.0e-04  4.4e-05  9.4e-07  7.03e-01   8.046146425e+00   8.045844630e+00   4.4e-05  1.75
# 14  1.5e-04  1.7e-05  2.3e-07  8.09e-01   7.995958057e+00   7.995828047e+00   1.7e-05  1.88
# 15  2.4e-05  2.7e-06  1.6e-08  9.00e-01   7.964934146e+00   7.964907646e+00   2.7e-06  2.02
# 16  3.3e-06  3.6e-07  8.4e-10  9.75e-01   7.958987145e+00   7.958983127e+00   3.6e-07  2.14
# 17  5.7e-07  6.4e-08  6.3e-11  1.00e+00   7.958087281e+00   7.958086537e+00   6.3e-08  2.27
# 18  9.8e-08  1.0e-08  4.1e-12  1.00e+00   7.957914148e+00   7.957914028e+00   1.0e-08  2.38
# 19  2.8e-08  3.3e-09  3.2e-13  1.00e+00   7.957886684e+00   7.957886663e+00   1.9e-09  2.52
# 20  5.3e-09  7.6e-09  2.4e-14  1.00e+00   7.957881816e+00   7.957881812e+00   3.3e-10  2.64
# Optimizer terminated. Time: 2.69
#
# SDP solving time: 2.8494322 seconds.
# optimum = 7.957881815822048
# Global optimality certified with relative optimality gap 0.000043%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0009705 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0464456 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8288              conic                  : 8288
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.16
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138399749e-01   2.522644469e-01   9.3e-01  0.28
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.357751749e-01  -1.036490059e+00  7.4e-01  0.38
# 3   3.9e+00  4.3e-01  5.8e-01  -8.78e-01  1.812787623e+00   8.737052263e-01   4.3e-01  0.50
# 4   1.4e+00  1.6e-01  1.6e-01  -5.54e-01  6.896394489e+00   6.249164604e+00   1.6e-01  0.64
# 5   1.1e+00  1.2e-01  1.1e-01  4.55e-01   7.657789468e+00   7.154092843e+00   1.2e-01  0.73
# 6   5.0e-01  5.5e-02  3.6e-02  7.41e-01   9.471918505e+00   9.220902719e+00   5.5e-02  0.86
# 7   1.2e-01  1.4e-02  4.7e-03  7.68e-01   1.039771524e+01   1.031955231e+01   1.4e-02  0.98
# 8   5.1e-02  5.7e-03  8.5e-04  1.49e+00   9.024369854e+00   9.014994730e+00   5.7e-03  1.09
# 9   2.4e-02  2.7e-03  2.9e-04  1.38e+00   7.484280733e+00   7.478712288e+00   2.7e-03  1.24
# 10  1.3e-02  1.5e-03  1.4e-04  8.31e-01   7.015761448e+00   7.010293691e+00   1.5e-03  1.34
# 11  2.3e-03  2.5e-04  1.4e-05  6.69e-01   5.813182855e+00   5.811122894e+00   2.5e-04  1.45
# 12  3.3e-04  3.6e-05  6.9e-07  9.06e-01   5.297946805e+00   5.297701970e+00   3.6e-05  1.59
# 13  5.6e-05  6.2e-06  5.2e-08  9.84e-01   5.226502635e+00   5.226453240e+00   6.2e-06  1.70
# 14  1.2e-05  1.3e-06  5.4e-09  9.97e-01   5.213809517e+00   5.213797859e+00   1.3e-06  1.84
# 15  2.2e-06  2.4e-07  4.3e-10  9.99e-01   5.210770566e+00   5.210768311e+00   2.4e-07  1.97
# 16  4.9e-07  5.3e-08  4.4e-11  1.00e+00   5.210218899e+00   5.210218391e+00   5.3e-08  2.09
# 17  1.5e-07  1.6e-08  7.6e-12  1.00e+00   5.210110013e+00   5.210109854e+00   1.6e-08  2.25
# 18  6.3e-08  1.3e-08  1.3e-12  1.00e+00   5.210075969e+00   5.210075920e+00   5.1e-09  2.34
# 19  2.0e-08  4.3e-09  2.2e-13  1.00e+00   5.210065239e+00   5.210065225e+00   1.6e-09  2.44
# 20  4.5e-09  3.4e-09  2.3e-14  1.00e+00   5.210061666e+00   5.210061663e+00   3.4e-10  2.56
# Optimizer terminated. Time: 2.56
#
# SDP solving time: 2.7442605 seconds.
# optimum = 5.210061665967244
# Global optimality certified with relative optimality gap 0.000020%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0012266 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0453995 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138632479e-01   2.522945171e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.381114477e-01  -1.039208764e+00  7.4e-01  0.42
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.820508694e+00   8.797210252e-01   4.3e-01  0.53
# 4   1.4e+00  1.6e-01  1.6e-01  -5.44e-01  6.876592697e+00   6.272019283e+00   1.6e-01  0.66
# 5   1.1e+00  1.3e-01  1.1e-01  4.68e-01   7.567840365e+00   7.109896515e+00   1.3e-01  0.77
# 6   4.9e-01  5.5e-02  3.2e-02  7.82e-01   9.282099230e+00   9.083323831e+00   5.5e-02  0.89
# 7   1.1e-01  1.2e-02  3.3e-03  8.85e-01   9.859449529e+00   9.819857445e+00   1.2e-02  1.00
# 8   4.6e-02  5.1e-03  6.7e-04  1.53e+00   7.798206416e+00   7.791870757e+00   5.1e-03  1.14
# 9   3.3e-02  3.7e-03  4.2e-04  1.24e+00   7.145829545e+00   7.140446299e+00   3.7e-03  1.25
# 10  1.1e-02  1.2e-03  1.0e-04  1.01e+00   6.354541253e+00   6.350447061e+00   1.2e-03  1.39
# 11  2.8e-03  3.1e-04  1.5e-05  5.39e-01   5.785756782e+00   5.784394904e+00   3.1e-04  1.50
# 12  4.5e-04  5.0e-05  1.1e-06  8.18e-01   5.343860239e+00   5.343547598e+00   5.0e-05  1.63
# 13  6.5e-05  7.3e-06  6.6e-08  9.11e-01   5.240792363e+00   5.240734110e+00   7.3e-06  1.75
# 14  2.9e-05  3.2e-06  2.0e-08  9.91e-01   5.229872886e+00   5.229846289e+00   3.2e-06  1.88
# 15  5.7e-06  6.3e-07  1.7e-09  9.95e-01   5.222672417e+00   5.222666950e+00   6.3e-07  1.98
# 16  9.2e-07  1.0e-07  1.1e-10  9.99e-01   5.221133758e+00   5.221132852e+00   1.0e-07  2.11
# 17  2.9e-07  3.1e-08  1.9e-11  1.00e+00   5.220923587e+00   5.220923305e+00   3.1e-08  2.23
# 18  4.4e-08  4.8e-09  1.1e-12  1.00e+00   5.220842230e+00   5.220842191e+00   4.5e-09  2.36
# 19  1.1e-08  2.6e-09  1.4e-13  1.00e+00   5.220832326e+00   5.220832315e+00   1.2e-09  2.48
# 20  1.7e-09  3.3e-09  7.7e-15  1.00e+00   5.220829357e+00   5.220829356e+00   1.7e-10  2.59
# Optimizer terminated. Time: 2.59
#
# SDP solving time: 2.7942563 seconds.
# optimum = 5.220829357409925
# Global optimality certified with relative optimality gap 0.000020%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0012839 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0420589 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.16
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138543394e-01   2.522826646e-01   9.3e-01  0.27
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.373166191e-01  -1.038331184e+00  7.4e-01  0.38
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.820309561e+00   8.790679023e-01   4.3e-01  0.50
# 4   1.4e+00  1.6e-01  1.6e-01  -5.46e-01  6.896215199e+00   6.282563291e+00   1.6e-01  0.63
# 5   1.1e+00  1.2e-01  1.1e-01  4.44e-01   7.660589845e+00   7.183536451e+00   1.2e-01  0.73
# 6   5.1e-01  5.6e-02  3.6e-02  7.40e-01   9.546842935e+00   9.306381288e+00   5.6e-02  0.83
# 7   1.2e-01  1.4e-02  4.8e-03  7.73e-01   1.087391582e+01   1.079447361e+01   1.4e-02  0.95
# 8   4.4e-02  4.9e-03  6.8e-04  1.39e+00   9.932352843e+00   9.924105558e+00   4.9e-03  1.08
# 9   3.5e-02  3.9e-03  4.9e-04  1.34e+00   9.396489601e+00   9.389214434e+00   3.9e-03  1.19
# 10  1.4e-02  1.5e-03  1.4e-04  1.20e+00   8.398349981e+00   8.393800496e+00   1.5e-03  1.33
# 11  6.6e-03  7.3e-04  6.0e-05  4.76e-01   8.169635038e+00   8.165158853e+00   7.3e-04  1.42
# 12  1.4e-03  1.6e-04  6.5e-06  7.10e-01   7.460130325e+00   7.458977965e+00   1.6e-04  1.56
# 13  1.6e-04  1.8e-05  2.6e-07  9.22e-01   7.191555894e+00   7.191415404e+00   1.8e-05  1.69
# 14  2.9e-05  3.2e-06  2.0e-08  9.88e-01   7.156841146e+00   7.156811918e+00   3.2e-06  1.81
# 15  5.5e-06  6.2e-07  1.8e-09  9.99e-01   7.150407254e+00   7.150400882e+00   6.2e-07  1.94
# 16  1.1e-06  1.2e-07  1.6e-10  1.00e+00   7.149075493e+00   7.149074153e+00   1.2e-07  2.06
# 17  2.1e-07  2.4e-08  1.4e-11  1.00e+00   7.148801268e+00   7.148801013e+00   2.3e-08  2.20
# 18  4.7e-08  5.4e-09  1.3e-12  1.00e+00   7.148750189e+00   7.148750136e+00   5.0e-09  2.31
# 19  8.9e-09  1.7e-09  1.1e-13  1.00e+00   7.148739124e+00   7.148739114e+00   9.3e-10  2.44
# 20  1.9e-09  7.1e-09  8.9e-15  1.00e+00   7.148737094e+00   7.148737092e+00   1.8e-10  2.56
# Optimizer terminated. Time: 2.56
#
# SDP solving time: 2.7903622 seconds.
# optimum = 7.148737094065422
# Global optimality certified with relative optimality gap 0.000008%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0200449 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0448119 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.02
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.05
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.19
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138317794e-01   2.522526024e-01   9.3e-01  0.30
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.356018124e-01  -1.036409322e+00  7.4e-01  0.41
# 3   3.9e+00  4.3e-01  5.8e-01  -8.78e-01  1.819003160e+00   8.766692777e-01   4.3e-01  0.52
# 4   1.4e+00  1.6e-01  1.6e-01  -5.51e-01  6.881834968e+00   6.227100555e+00   1.6e-01  0.64
# 5   1.1e+00  1.2e-01  1.1e-01  4.39e-01   7.647699842e+00   7.143559498e+00   1.2e-01  0.75
# 6   4.9e-01  5.4e-02  3.4e-02  7.38e-01   9.547047554e+00   9.307527481e+00   5.4e-02  0.88
# 7   1.0e-01  1.1e-02  3.5e-03  8.22e-01   1.099957829e+01   1.094081398e+01   1.1e-02  0.98
# 8   3.9e-02  4.4e-03  5.5e-04  1.56e+00   1.029035641e+01   1.028381119e+01   4.4e-03  1.13
# 9   2.7e-02  3.0e-03  3.2e-04  1.27e+00   9.717304755e+00   9.712262840e+00   3.0e-03  1.23
# 10  2.1e-02  2.4e-03  2.5e-04  9.48e-01   9.575497435e+00   9.570131080e+00   2.4e-03  1.36
# 11  4.9e-03  5.5e-04  3.6e-05  8.73e-01   8.969965110e+00   8.967037466e+00   5.5e-04  1.48
# 12  1.3e-03  1.4e-04  5.3e-06  7.15e-01   8.640239361e+00   8.639313747e+00   1.4e-04  1.61
# 13  2.4e-04  2.6e-05  5.1e-07  6.98e-01   8.535352976e+00   8.535079667e+00   2.6e-05  1.73
# 14  3.3e-05  3.6e-06  2.8e-08  9.03e-01   8.470687058e+00   8.470643537e+00   3.6e-06  1.86
# 15  1.5e-05  1.7e-06  8.8e-09  9.81e-01   8.465467888e+00   8.465447097e+00   1.7e-06  1.97
# 16  2.9e-06  3.2e-07  7.5e-10  9.92e-01   8.461683038e+00   8.461678796e+00   3.2e-07  2.11
# 17  4.5e-07  4.9e-08  4.6e-11  9.98e-01   8.460865495e+00   8.460864823e+00   4.9e-08  2.22
# 18  1.2e-07  1.2e-08  5.1e-12  1.00e+00   8.460744914e+00   8.460744765e+00   1.1e-08  2.36
# 19  2.0e-08  4.1e-09  2.5e-13  1.00e+00   8.460715667e+00   8.460715648e+00   1.5e-09  2.50
# 20  8.1e-09  1.2e-08  5.2e-14  1.00e+00   8.460712751e+00   8.460712744e+00   5.4e-10  2.63
# 21  4.0e-09  9.0e-09  3.3e-15  1.00e+00   8.460711442e+00   8.460711441e+00   8.6e-11  2.75
# Optimizer terminated. Time: 2.75
#
# SDP solving time: 2.9155991 seconds.
# optimum = 8.460711441694773
# Global optimality certified with relative optimality gap 0.000009%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0008985 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0456361 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.01
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.01
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138638193e-01   2.522955156e-01   9.3e-01  0.30
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.382389281e-01  -1.039323108e+00  7.4e-01  0.39
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.818692867e+00   8.779782351e-01   4.3e-01  0.50
# 4   1.5e+00  1.7e-01  1.8e-01  -5.51e-01  6.641801408e+00   5.952546806e+00   1.7e-01  0.64
# 5   1.2e+00  1.3e-01  1.3e-01  3.60e-01   7.356840988e+00   6.781727458e+00   1.3e-01  0.75
# 6   5.4e-01  6.0e-02  4.1e-02  6.55e-01   9.164100071e+00   8.875461267e+00   6.0e-02  0.86
# 7   1.4e-01  1.5e-02  6.7e-03  7.28e-01   1.040467420e+01   1.027356684e+01   1.5e-02  1.00
# 8   2.8e-02  3.1e-03  6.1e-04  7.84e-01   1.028251152e+01   1.025682189e+01   3.1e-03  1.11
# 9   1.0e-02  1.2e-03  8.1e-05  1.75e+00   8.905208134e+00   8.903086365e+00   1.2e-03  1.23
# 10  4.5e-03  5.1e-04  2.3e-05  1.48e+00   8.463683227e+00   8.462613431e+00   5.1e-04  1.36
# 11  2.9e-03  3.3e-04  1.4e-05  9.03e-01   8.423964702e+00   8.422958100e+00   3.3e-04  1.47
# 12  7.6e-04  8.5e-05  2.4e-06  7.66e-01   8.334969150e+00   8.334431526e+00   8.5e-05  1.59
# 13  1.9e-04  2.1e-05  4.0e-07  5.44e-01   8.341237514e+00   8.340960262e+00   2.1e-05  1.72
# 14  4.8e-05  5.4e-06  6.2e-08  5.84e-01   8.338127773e+00   8.338020062e+00   5.4e-06  1.84
# 15  1.3e-05  1.4e-06  9.5e-09  7.49e-01   8.333603378e+00   8.333566768e+00   1.4e-06  1.97
# 16  1.7e-06  1.9e-07  4.8e-10  8.89e-01   8.330312337e+00   8.330306677e+00   1.9e-07  2.09
# 17  7.6e-07  8.4e-08  1.5e-10  9.85e-01   8.329978338e+00   8.329975724e+00   8.4e-08  2.20
# 18  1.4e-07  1.6e-08  1.3e-11  9.93e-01   8.329749719e+00   8.329749202e+00   1.6e-08  2.33
# 19  2.4e-08  2.6e-09  7.7e-13  9.99e-01   8.329702631e+00   8.329702553e+00   2.5e-09  2.44
# 20  2.0e-08  5.4e-09  7.7e-14  1.00e+00   8.329696450e+00   8.329696433e+00   5.4e-10  2.58
# 21  1.0e-08  6.9e-08  5.6e-15  1.00e+00   8.329695063e+00   8.329695060e+00   9.4e-11  2.70
# 22  3.6e-09  2.9e-08  1.2e-15  1.00e+00   8.329694874e+00   8.329694873e+00   3.3e-11  2.86
# Optimizer terminated. Time: 2.86
#
# SDP solving time: 3.0422294 seconds.
# optimum = 8.3296948744485
# Global optimality certified with relative optimality gap 0.000048%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0015427 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0725439 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8288              conic                  : 8288
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.17              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.19
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138700007e-01   2.523043554e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.381429487e-01  -1.039143462e+00  7.4e-01  0.44
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.814633276e+00   8.770571321e-01   4.3e-01  0.55
# 4   1.4e+00  1.5e-01  1.5e-01  -5.45e-01  7.114101179e+00   6.555611093e+00   1.5e-01  0.67
# 5   1.1e+00  1.2e-01  1.0e-01  5.75e-01   7.868720741e+00   7.470662341e+00   1.2e-01  0.78
# 6   3.3e-01  3.7e-02  1.7e-02  8.41e-01   9.922118091e+00   9.805837905e+00   3.7e-02  0.91
# 7   1.0e-01  1.1e-02  2.0e-03  9.44e-01   9.928394595e+00   9.922591205e+00   1.1e-02  1.05
# ...
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.19
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138835552e-01   2.523218747e-01   9.3e-01  0.39
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.396265770e-01  -1.040885682e+00  7.4e-01  0.52
# 3   3.9e+00  4.3e-01  5.8e-01  -8.77e-01  1.822068526e+00   8.819497514e-01   4.3e-01  0.63
# 4   1.3e+00  1.5e-01  1.4e-01  -5.38e-01  7.239985031e+00   6.726284857e+00   1.5e-01  0.75
# 5   1.0e+00  1.1e-01  9.1e-02  6.53e-01   8.036258413e+00   7.693501526e+00   1.1e-01  0.88
# 6   3.0e-01  3.3e-02  1.4e-02  8.95e-01   9.984801576e+00   9.894680469e+00   3.3e-02  1.02
# 7   8.9e-02  9.8e-03  1.5e-03  1.07e+00   9.960215969e+00   9.958017264e+00   9.8e-03  1.16
# 8   4.3e-02  4.8e-03  5.2e-04  1.43e+00   9.200855509e+00   9.198076089e+00   4.8e-03  1.28
# 9   2.9e-02  3.3e-03  3.4e-04  9.10e-01   9.103693644e+00   9.099995674e+00   3.3e-03  1.42
# 10  7.0e-03  7.7e-04  5.3e-05  7.73e-01   8.867244048e+00   8.864503491e+00   7.7e-04  1.56
# 11  1.8e-03  2.0e-04  8.3e-06  6.84e-01   8.853777323e+00   8.852596114e+00   2.0e-04  1.69
# 12  4.1e-04  4.6e-05  1.3e-06  5.91e-01   8.974534203e+00   8.973885108e+00   4.6e-05  1.83
# 13  1.1e-04  1.2e-05  2.5e-07  4.85e-01   9.092430403e+00   9.092070301e+00   1.2e-05  1.95
# 14  2.8e-05  3.1e-06  4.5e-08  4.90e-01   9.161237698e+00   9.161058214e+00   3.1e-06  2.09
# 15  8.8e-06  9.8e-07  9.7e-09  5.62e-01   9.190982371e+00   9.190894011e+00   9.8e-07  2.22
# 16  3.4e-06  3.8e-07  2.7e-09  6.89e-01   9.200415406e+00   9.200368512e+00   3.8e-07  2.34
# 17  6.6e-07  7.2e-08  2.6e-10  7.98e-01   9.204790059e+00   9.204778069e+00   7.2e-08  2.47
# 18  1.7e-07  1.1e-08  1.6e-11  8.98e-01   9.205610562e+00   9.205608571e+00   1.1e-08  2.59
# 19  1.3e-07  6.8e-09  5.3e-12  9.87e-01   9.205672838e+00   9.205671856e+00   5.1e-09  2.70
# 20  4.5e-08  2.1e-09  9.0e-13  9.96e-01   9.205716371e+00   9.205716069e+00   1.6e-09  2.89
# 21  1.1e-08  1.2e-09  1.2e-13  9.98e-01   9.205731302e+00   9.205731223e+00   4.1e-10  3.03
# 22  1.9e-09  1.6e-09  1.1e-14  1.00e+00   9.205735850e+00   9.205735834e+00   8.4e-11  3.22
# Optimizer terminated. Time: 3.22
#
# SDP solving time: 3.3992062 seconds.
# optimum = 9.205735850082688
# Global optimality certified with relative optimality gap 0.000078%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0009896 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0443926 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.02
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.02
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.13              dense det. time        : 0.00
# Factor     - ML order time          : 0.03              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.16
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138324948e-01   2.522536870e-01   9.3e-01  0.30
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.357225306e-01  -1.036526295e+00  7.4e-01  0.41
# 3   3.9e+00  4.3e-01  5.8e-01  -8.78e-01  1.820309515e+00   8.777738598e-01   4.3e-01  0.53
# 4   1.3e+00  1.5e-01  1.4e-01  -5.48e-01  7.224442932e+00   6.637143742e+00   1.5e-01  0.64
# 5   1.0e+00  1.1e-01  9.1e-02  6.58e-01   8.012729233e+00   7.634925208e+00   1.1e-01  0.77
# 6   2.7e-01  3.0e-02  1.2e-02  8.88e-01   9.808081789e+00   9.723484430e+00   3.0e-02  0.89
# 7   7.4e-02  8.2e-03  1.1e-03  1.20e+00   9.137454409e+00   9.134366816e+00   8.2e-03  1.03
# 8   3.5e-02  3.9e-03  4.1e-04  1.36e+00   7.610785314e+00   7.607342212e+00   3.9e-03  1.19
# 9   2.5e-02  2.8e-03  2.8e-04  8.60e-01   7.390734690e+00   7.386678247e+00   2.8e-03  1.31
# 10  6.5e-03  7.2e-04  4.5e-05  7.90e-01   6.523879422e+00   6.521796149e+00   7.2e-04  1.44
# 11  1.5e-03  1.7e-04  5.6e-06  7.63e-01   5.959175617e+00   5.958515592e+00   1.7e-04  1.58
# 12  2.0e-04  2.2e-05  3.2e-07  8.19e-01   5.726817155e+00   5.726670204e+00   2.2e-05  1.70
# 13  1.7e-04  1.9e-05  2.5e-07  9.44e-01   5.717630579e+00   5.717504277e+00   1.9e-05  1.86
# 14  2.7e-05  3.0e-06  1.7e-08  9.74e-01   5.673153889e+00   5.673132060e+00   3.0e-06  1.97
# 15  5.1e-06  5.7e-07  1.4e-09  9.92e-01   5.666702691e+00   5.666698278e+00   5.7e-07  2.11
# 16  1.2e-06  1.4e-07  1.7e-10  9.99e-01   5.665507581e+00   5.665506509e+00   1.4e-07  2.23
# 17  1.9e-07  2.2e-08  1.1e-11  1.00e+00   5.665187521e+00   5.665187347e+00   2.1e-08  2.38
# 18  4.3e-08  1.2e-08  9.3e-13  1.00e+00   5.665137356e+00   5.665137323e+00   4.2e-09  2.50
# 19  1.3e-08  5.4e-09  8.0e-14  1.00e+00   5.665127687e+00   5.665127680e+00   8.3e-10  2.66
# 20  3.0e-09  3.8e-08  8.1e-15  1.00e+00   5.665125900e+00   5.665125899e+00   1.8e-10  2.78
# Optimizer terminated. Time: 2.80
#
# SDP solving time: 2.9941796 seconds.
# optimum = 5.665125900120074
# Global optimality certified with relative optimality gap 0.000020%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0010144 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0424941 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.02
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.03
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.14              dense det. time        : 0.00
# Factor     - ML order time          : 0.05              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.17
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138427322e-01   2.522676667e-01   9.3e-01  0.31
# 2   6.6e+00  7.4e-01  8.9e-01  -1.20e+00  -6.361198144e-01  -1.036974291e+00  7.4e-01  0.42
# 3   3.9e+00  4.3e-01  5.8e-01  -8.78e-01  1.819383363e+00   8.771835117e-01   4.3e-01  0.56
# 4   1.3e+00  1.5e-01  1.5e-01  -5.50e-01  7.152049765e+00   6.534248264e+00   1.5e-01  0.70
# 5   1.0e+00  1.2e-01  1.0e-01  5.67e-01   7.943212396e+00   7.495286423e+00   1.2e-01  0.81
# 6   3.1e-01  3.5e-02  1.7e-02  7.92e-01   1.021026377e+01   1.007444212e+01   3.5e-02  0.94
# 7   7.4e-02  8.2e-03  1.2e-03  9.38e-01   1.109293489e+01   1.109297389e+01   8.2e-03  1.08
# 8   3.4e-02  3.8e-03  3.6e-04  1.64e+00   9.963243493e+00   9.961455022e+00   3.8e-03  1.19
# 9   2.6e-02  2.9e-03  2.6e-04  1.03e+00   9.736523431e+00   9.734168218e+00   2.9e-03  1.31
# 10  7.0e-03  7.8e-04  4.8e-05  9.19e-01   9.045005171e+00   9.043079590e+00   7.8e-04  1.45
# 11  2.3e-03  2.6e-04  1.1e-05  6.52e-01   8.666217037e+00   8.665186627e+00   2.6e-04  1.56
# 12  6.1e-04  6.8e-05  1.7e-06  7.48e-01   8.444736137e+00   8.444343078e+00   6.8e-05  1.72
# 13  8.6e-05  9.5e-06  9.9e-08  8.91e-01   8.320109553e+00   8.320032880e+00   9.5e-06  1.88
# 14  1.6e-05  1.8e-06  8.4e-09  9.73e-01   8.299917830e+00   8.299902240e+00   1.8e-06  2.00
# 15  3.3e-06  3.6e-07  7.7e-10  9.95e-01   8.295976573e+00   8.295973263e+00   3.6e-07  2.13
# 16  6.3e-07  7.0e-08  6.6e-11  9.99e-01   8.295135733e+00   8.295135082e+00   6.9e-08  2.27
# 17  1.9e-07  1.5e-08  6.6e-12  1.00e+00   8.294977651e+00   8.294977503e+00   1.5e-08  2.41
# 18  3.4e-08  7.8e-09  5.0e-13  1.00e+00   8.294939041e+00   8.294939016e+00   2.7e-09  2.53
# 19  7.7e-09  6.2e-09  5.2e-14  1.00e+00   8.294932891e+00   8.294932885e+00   5.9e-10  2.67
# Optimizer terminated. Time: 2.67
#
# SDP solving time: 2.8372848 seconds.
# optimum = 8.294932890828902
# Global optimality certified with relative optimality gap 0.000040%!
# *********************************** TSSOS ***********************************
# Version 1.0.0, developed by Jie Wang, 2020--2023
# TSSOS is launching...
# -----------------------------------------------------------------------------
# The clique sizes of varibles:
# [9, 8, 6, 2, 4, 3]
# [6, 11, 18, 30, 9, 6]
# -----------------------------------------------------------------------------
# Obtained the variable cliques in 0.0008533 seconds. The maximal size of cliques is 9.
# Assembling the SDP...
# There are 9762 affine constraints.
# SDP assembling time: 0.0468954 seconds.
# Solving the SDP...
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator started.
# Freed constraints in eliminator : 0
# Eliminator terminated.
# Eliminator - tries                  : 2                 time                   : 0.00
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 9762
#   Cones                  : 0
#   Scalar variables       : 9916
#   Matrix variables       : 115
#   Integer variables      : 0
#
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 9762
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 8285              conic                  : 8285
# Optimizer  - Semi-definite variables: 115               scalarized             : 31032
# Factor     - setup time             : 0.16              dense det. time        : 0.00
# Factor     - ML order time          : 0.06              GP order time          : 0.00
# Factor     - nonzeros before factor : 2.99e+06          after factor           : 3.74e+06
# Factor     - dense dim.             : 2                 flops                  : 1.85e+09
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   9.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.19
# 1   8.4e+00  9.3e-01  8.6e-01  1.33e+00   2.138561161e-01   2.522849025e-01   9.3e-01  0.33
